# %% [markdown]
# ## 1. 环境准备

# %%
import pandas as pd
from notebooks.utils.eda_utils import eda_preprocess, dataset_overview,plot_distributions, target_analysis

# %% [markdown]
# ## 2. 数据加载

# %%
df = pd.read_csv("../data/WA_Fn-UseC_-Telco-Customer-Churn.csv")
print("=== 所有列的数据类型 ===")
print(df.dtypes)
print("\n")
# Out:
# === 所有列的数据类型 ===
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# ## 3. 数据清洗

# %%
df = eda_preprocess(df)
df = df.drop(columns=['customerID'], errors='ignore')
# Out:
# === 缺失值分析 ===
#               缺失数量     缺失比例%
# TotalCharges    11  0.156183
# [清洗] TotalCharges 填充缺失 11 条
# [清洗] 数值缺失已用中位数填充：['tenure', 'MonthlyCharges']
# [清洗] 无重复行

# %% [markdown]
# ## 4. 数据总体概况

# %%
print("==== 1. 数据总体概况 ====")
display(dataset_overview(df))
# Out:
# ==== 1. 数据总体概况 ====
#              feature         type  valid_count    min     max     mean  \
# 0             gender  categorical         7043      -       -        -
# 1      SeniorCitizen  categorical         7043      -       -        -
# 2            Partner  categorical         7043      -       -        -
# 3         Dependents  categorical         7043      -       -        -
# 4             tenure      numeric         7043    0.0    72.0    32.37
# 5       PhoneService  categorical         7043      -       -        -
# 6      MultipleLines  categorical         7043      -       -        -
# 7    InternetService  categorical         7043      -       -        -
# 8     OnlineSecurity  categorical         7043      -       -        -
# 9       OnlineBackup  categorical         7043      -       -        -
# 10  DeviceProtection  categorical         7043      -       -        -
# 11       TechSupport  categorical         7043      -       -        -
# 12       StreamingTV  categorical         7043      -       -        -
# 13   StreamingMovies  categorical         7043      -       -        -
# 14          Contract  categorical         7043      -       -        -
# 15  PaperlessBilling  categorical         7043      -       -        -
# 16     PaymentMethod  categorical         7043      -       -        -
# 17    MonthlyCharges      numeric         7043  18.25  118.75    64.76
# 18      TotalCharges      numeric         7043    0.0  8684.8  2279.73
# 19             Churn  categorical         7043      -       -        -
#
#         std  skew                              detail
# 0         -     -              2 类别, 最常见 Male (50.5%)
# 1         -     -                 2 类别, 最常见 0 (83.8%)
# 2         -     -                2 类别, 最常见 No (51.7%)
# 3         -     -                2 类别, 最常见 No (70.0%)
# 4     24.56  0.24                                数值特征
# 5         -     -               2 类别, 最常见 Yes (90.3%)
# 6         -     -                3 类别, 最常见 No (48.1%)
# 7         -     -       3 类别, 最常见 Fiber optic (44.0%)
# 8         -     -                3 类别, 最常见 No (49.7%)
# 9         -     -                3 类别, 最常见 No (43.8%)
# 10        -     -                3 类别, 最常见 No (43.9%)
# 11        -     -                3 类别, 最常见 No (49.3%)
# 12        -     -                3 类别, 最常见 No (39.9%)
# 13        -     -                3 类别, 最常见 No (39.5%)
# 14        -     -    3 类别, 最常见 Month-to-month (55.0%)
# 15        -     -               2 类别, 最常见 Yes (59.2%)
# 16        -     -  4 类别, 最常见 Electronic check (33.6%)
# 17    30.09 -0.22                                数值特征
# 18  2266.79  0.96                                数值特征
# 19        -     -                2 类别, 最常见 No (73.5%)

# %% [markdown]
# ## 5. 单变量分析

# %%
print("\n==== 2. 特征分布 ====")
plot_distributions(df)
# Out:
# ==== 2. 特征分布 ====

# %% [markdown]
# ## 6. 目标变量分析

# %%
print("\n==== 3. 目标变量分析 ====")
target_analysis(df)
# Out:
# ==== 3. 目标变量分析 ====
